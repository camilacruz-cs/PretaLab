# %% [markdown]
# <a href="https://colab.research.google.com/github/camilacruz-cs/PretaLab/blob/main/mod3/%20aula2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Montando o drive

# %%
# Montando o Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/PretaLab - Python para análise de dados/
# Out:
# /content/drive/MyDrive/Colab Notebooks/PretaLab - Python para análise de dados

# %%
import os
print(os.getcwd())
# Out:
# /content/drive/MyDrive/Colab Notebooks/PretaLab - Python para análise de dados

# %%
# !ls
# Out:
# 'Módulo 1'  'Módulo 2'	'Módulo 3'  'Módulo 4'	'Módulo 5'   Projetos

# %% [markdown]
# ##Métodos avançados com Biblioteca Python para análise de dados

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os

# %% [markdown]
# PNAD CONTINUA DE 2024 - 2 TRIMESTRE (ABRIL-MAIO-JUNHO)
#
# * Coluna idade = Varia entre 19 e 65 anos.

# %%
#Leitura dos dados

pnad = pd.read_csv('/content/pnad - pnad.csv')
pnad
# Out:
#          ano sigla_uf sigla_uf_nome        id_pessoa   V2007  V2009  V2010  \
# 0       2024       AP         Amapá  160000321011101  Mulher     27      4
# 1       2024       AP         Amapá  160000321021101  Mulher     33      4
# 2       2024       AP         Amapá  160000321021102   Homem     27      4
# 3       2024       AP         Amapá  160000321031104  Mulher     27      1
# 4       2024       AP         Amapá  160000321031102  Mulher     78      4
# ...      ...      ...           ...              ...     ...    ...    ...
# 365663  2024       BA         Bahia  290026766051101  Mulher     45      5
# 365664  2024       BA         Bahia  290250365101101   Homem     22      2
# 365665  2024       BA         Bahia  290211270071102  Mulher     29      4
# 365666  2024       BA         Bahia  290083340131101  Mulher     19      2
# 365667  2024       BA         Bahia  290263738021102  Mulher     60      4
#
# ...

# %%
pnad.head(4)
# Out:
#     ano sigla_uf sigla_uf_nome        id_pessoa   V2007  V2009  V2010  V4001  \
# 0  2024       AP         Amapá  160000321011101  Mulher     27      4      1
# 1  2024       AP         Amapá  160000321021101  Mulher     33      4      2
# 2  2024       AP         Amapá  160000321021102   Homem     27      4      1
# 3  2024       AP         Amapá  160000321031104  Mulher     27      1      2
#
#    V4003  V4009  ...  V4033  V403412  V4039  V4039C  V4040  V4043  V40431  \
# 0    NaN    1.0  ...    1.0   1200.0   36.0    36.0    2.0    NaN     NaN
# 1    2.0    NaN  ...    NaN      NaN    NaN     NaN    NaN    NaN     NaN
# 2    NaN    1.0  ...    1.0    800.0   30.0    30.0    4.0    NaN     NaN
# 3    2.0    NaN  ...    NaN      NaN    NaN     NaN    NaN    NaN     NaN
#
#    V4048  V405012  V4056
# 0    NaN      NaN    NaN
# 1    NaN      NaN    NaN
# 2    NaN      NaN    NaN
# 3    NaN      NaN    NaN
#
# [4 rows x 26 columns]

# %%
pnad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365668 entries, 0 to 365667
# Data columns (total 26 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ano            365668 non-null  int64
#  1   sigla_uf       365668 non-null  object
#  2   sigla_uf_nome  365668 non-null  object
#  3   id_pessoa      365668 non-null  int64
#  4   V2007          365668 non-null  object
#  5   V2009          365668 non-null  int64
#  6   V2010          365668 non-null  int64
#  7   V4001          365668 non-null  int64
#  8   V4003          172177 non-null  float64
#  9   V4009          207824 non-null  float64
#  10  V4010          207824 non-null  float64
#  11  V40121         4144 non-null    float64
#  12  V4014          28733 non-null   float64
#  13  V40151         5191 non-null    float64
#  14  V4028          19283 non-null   float64
#  15  V4029          120211 non-null  float64
#  16  V4033          203680 non-null  float64
# ...

# %% [markdown]
# ###Tratamento e limpeza de dados - ETL

# %%
# 2. Renomear as colunas com base no dicionário fornecido
colunas_dicionario = {
    'V2007': 'sexo',
    'V4009': 'idade',
    'V4001': 'condicao_de_trabalho',
    'V4003': 'renda',
    'sigla_uf': 'estado',
    'V2010': 'raca_cor',
    'V4039': 'horas_trabalhadas'
}

# %%
df = pnad.rename(columns=colunas_dicionario)
df
# Out:
#          ano estado sigla_uf_nome        id_pessoa    sexo  raca_cor  V2010  \
# 0       2024     AP         Amapá  160000321011101  Mulher        27      4
# 1       2024     AP         Amapá  160000321021101  Mulher        33      4
# 2       2024     AP         Amapá  160000321021102   Homem        27      4
# 3       2024     AP         Amapá  160000321031104  Mulher        27      1
# 4       2024     AP         Amapá  160000321031102  Mulher        78      4
# ...      ...    ...           ...              ...     ...       ...    ...
# 365663  2024     BA         Bahia  290026766051101  Mulher        45      5
# 365664  2024     BA         Bahia  290250365101101   Homem        22      2
# 365665  2024     BA         Bahia  290211270071102  Mulher        29      4
# 365666  2024     BA         Bahia  290083340131101  Mulher        19      2
# 365667  2024     BA         Bahia  290263738021102  Mulher        60      4
#
# ...

# %%
df.columns
# Out:
# Index(['ano', 'estado', 'sigla_uf_nome', 'id_pessoa', 'sexo', 'raca_cor',
#        'V2010', 'condicao_de_trabalho', 'renda', 'idade', 'V4010', 'V40121',
#        'V4014', 'V40151', 'V4028', 'V4029', 'V4033', 'V403412',
#        'horas_trabalhadas', 'V4039C', 'V4040', 'V4043', 'V40431', 'V4048',
#        'V405012', 'V4056'],
#       dtype='object')

# %%
pnad_renomeada = pnad_renomeada.DataFrame(pnad_renomeada, columns=['ano', 'estado','sigla_uf_nome','id_pessoa','sexo','idade', 'raca_cor','condicao_de_trabalho','trabalho_informal','renda'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-60fd525b0cf4> in <cell line: 1>()
# ----> 1 pnad_renomeada = pnad_renomeada.DataFrame(pnad_renomeada, columns=['ano', 'estado','sigla_uf_nome','id_pessoa','sexo','idade', 'raca_cor','condicao_de_trabalho','trabalho_informal','renda'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'DataFrame'
